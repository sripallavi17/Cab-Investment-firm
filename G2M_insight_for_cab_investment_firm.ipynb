# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('C:/Users/pallu/Desktop/Virtual Internship/week 2/Cab_Data.csv')
df2 = pd.read_csv('C:/Users/pallu/Desktop/Virtual Internship/week 2/City.csv')
df3 = pd.read_csv('C:/Users/pallu/Desktop/Virtual Internship/week 2/Customer_ID.csv')
df4 = pd.read_csv('C:/Users/pallu/Desktop/Virtual Internship/week 2/Transaction_ID.csv')

# %%
df1.head()
df1.info()
df1.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  object
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 19.2+ MB
#        Transaction ID   KM Travelled  Price Charged   Cost of Trip
# count    3.593920e+05  359392.000000  359392.000000  359392.000000
# mean     1.022076e+07      22.567254     423.443311     286.190113
# std      1.268058e+05      12.233526     274.378911     157.993661
# min      1.000001e+07       1.900000      15.600000      19.000000
# ...

# %%
df2.head()
df2.info()
df2.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     object
#  2   Users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes
#                City Population    Users
# count            20         20       20
# unique           20         20       20
# top     NEW YORK NY  8,405,837  302,149
# freq              1          1        1

# %%
df3.head()
df3.info()
df3.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
#         Customer ID           Age  Income (USD/Month)
# count  49171.000000  49171.000000        49171.000000
# mean   28398.252283     35.363121        15015.631856
# std    17714.137333     12.599066         8002.208253
# min        1.000000     18.000000         2000.000000
# 25%    12654.500000     25.000000         8289.500000
# 50%    27631.000000     33.000000        14656.000000
# 75%    43284.500000     42.000000        21035.000000
# max    60000.000000     65.000000        35000.000000

# %%
df4.head()
df4.info()
df4.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB
#        Transaction ID    Customer ID
# count    4.400980e+05  440098.000000
# mean     1.022006e+07   23619.513120
# std      1.270455e+05   21195.549816
# min      1.000001e+07       1.000000
# 25%      1.011004e+07    3530.000000
# 50%      1.022006e+07   15168.000000
# 75%      1.033008e+07   43884.000000
# max      1.044011e+07   60000.000000

# %%
merge_df1 = pd.merge(df1, df4, on ='Transaction ID')

# %%
merge_df1.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip  Customer ID Payment_Mode
# 0         370.95       313.635        29290         Card
# 1         358.52       334.854        27703         Card
# 2         125.20        97.632        28712         Cash
# 3         377.40       351.602        28020         Cash
# 4         114.62        97.776        27182         Card

# %%
merge_df2 = pd.merge(df3, df4, on ='Customer ID')

# %%
merge_df2.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)  Transaction ID Payment_Mode
# 0        29290   Male   28               10813        10000011         Card
# 1        29290   Male   28               10813        10351127         Cash
# 2        29290   Male   28               10813        10412921         Card
# 3        27703   Male   27                9237        10000012         Card
# 4        27703   Male   27                9237        10320494         Card

# %%
merge_3files = pd.merge(merge_df1, merge_df2, on = 'Transaction ID')

# %%
merge_3files.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip  Customer ID_x Payment_Mode_x  Customer ID_y  \
# 0         370.95       313.635          29290           Card          29290
# 1         358.52       334.854          27703           Card          27703
# 2         125.20        97.632          28712           Cash          28712
# 3         377.40       351.602          28020           Cash          28020
# 4         114.62        97.776          27182           Card          27182
#
#   Gender  Age  Income (USD/Month) Payment_Mode_y
# ...

# %%
merge_final = pd.merge(merge_3files, df2, on = 'City')

# %%
merge_final.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip  Customer ID_x Payment_Mode_x  Customer ID_y  \
# 0         370.95       313.635          29290           Card          29290
# 1         358.52       334.854          27703           Card          27703
# 2         125.20        97.632          28712           Cash          28712
# 3         377.40       351.602          28020           Cash          28020
# 4         114.62        97.776          27182           Card          27182
#
#   Gender  Age  Income (USD/Month) Payment_Mode_y Population   Users
# ...

# %%
print(merge_final.columns)
# Out:
# Index(['Transaction ID', 'Date of Travel', 'Company', 'City', 'KM Travelled',
#        'Price Charged', 'Cost of Trip', 'Customer ID_x', 'Payment_Mode_x',
#        'Customer ID_y', 'Gender', 'Age', 'Income (USD/Month)',
#        'Payment_Mode_y', 'Population', 'Users'],
#       dtype='object')

# %%
# merge_final['Date of Travel'.strip()]

# %%
# merge_final.drop(['Date of Travel'], axis=1, inplace=True)

# %%
merge_final.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip  Customer ID_x Payment_Mode_x  Customer ID_y  \
# 0         370.95       313.635          29290           Card          29290
# 1         358.52       334.854          27703           Card          27703
# 2         125.20        97.632          28712           Cash          28712
# 3         377.40       351.602          28020           Cash          28020
# 4         114.62        97.776          27182           Card          27182
#
#   Gender  Age  Income (USD/Month) Payment_Mode_y Population   Users
# ...

# %%
duplicates = merge_final.duplicated()
print(duplicates)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 359387    False
# 359388    False
# 359389    False
# 359390    False
# 359391    False
# Length: 359392, dtype: bool

# %%
missing_values = merge_final.isnull()
print(missing_values)
# Out:
#         Transaction ID  Date of Travel  Company   City  KM Travelled  \
# 0                False           False    False  False         False
# 1                False           False    False  False         False
# 2                False           False    False  False         False
# 3                False           False    False  False         False
# 4                False           False    False  False         False
# ...                ...             ...      ...    ...           ...
# 359387           False           False    False  False         False
# 359388           False           False    False  False         False
# 359389           False           False    False  False         False
# 359390           False           False    False  False         False
# 359391           False           False    False  False         False
#
#         Price Charged  Cost of Trip  Customer ID_x  Payment_Mode_x  \
# 0               False         False          False           False
# ...

# %%
missing_counts = merge_final.isnull().sum()
print(missing_counts)
# Out:
# Transaction ID        0
# Date of Travel        0
# Company               0
# City                  0
# KM Travelled          0
# Price Charged         0
# Cost of Trip          0
# Customer ID_x         0
# Payment_Mode_x        0
# Customer ID_y         0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# Payment_Mode_y        0
# Population            0
# Users                 0
# dtype: int64

# %%
merge_final.info()
merge_final.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 0 to 359391
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Transaction ID      359392 non-null  int64
#  1   Date of Travel      359392 non-null  object
#  2   Company             359392 non-null  object
#  3   City                359392 non-null  object
#  4   KM Travelled        359392 non-null  float64
#  5   Price Charged       359392 non-null  float64
#  6   Cost of Trip        359392 non-null  float64
#  7   Customer ID_x       359392 non-null  int64
#  8   Payment_Mode_x      359392 non-null  object
#  9   Customer ID_y       359392 non-null  int64
#  10  Gender              359392 non-null  object
#  11  Age                 359392 non-null  int64
#  12  Income (USD/Month)  359392 non-null  int64
#  13  Payment_Mode_y      359392 non-null  object
#  14  Population          359392 non-null  object
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
train_val, test = train_test_split(merge_final, test_size=0.2, random_state=42)
train, val = train_test_split(train_val, test_size=0.5, random_state=42)

# %%
print("Training set size:", len(train))
print("Validation set size:", len(val))
print("Test set size:", len(test))
print("Total:", len(merge_final))
# Out:
# Training set size: 143756
# Validation set size: 143757
# Test set size: 71879
# Total: 359392

# %%
# Z score
#import numpy as np
#from scipy import stats

# %%
#column = train['KM Travelled']
#Q1 = np.percentile(column, 25)
#Q3 = np.percentile(column, 75)
#IQR = Q3 - Q1
#lower_bound = Q1 - 1.5 * IQR
#upper_bound = Q3 + 1.5 * IQR

# %%
#outliers = column[(column < lower_bound) | (column > upper_bound)]

# %%
#outliers.head()
# Out:
# Series([], Name: KM Travelled, dtype: float64)

# %%
# Box plot

import matplotlib.pyplot as plt

# %%
data = train[['KM Travelled']]
plt.boxplot(data.values)
plt.xticks(range(1, len(data.columns) + 1), data.columns)
plt.title('Box Plot of KM Travelled')
plt.ylabel('KM Values')
plt.show()

# %%
data = train[['Price Charged']]
plt.boxplot(data.values)
plt.xticks(range(1, len(data.columns) + 1), data.columns)
plt.title('Box Plot of Price Charged')
plt.ylabel('Feature Values')
plt.show()

# %%
data = train[['Cost of Trip']]
plt.boxplot(data.values)
plt.xticks(range(1, len(data.columns) + 1), data.columns)
plt.title('Box Plot of Trip Cost')
plt.ylabel('Feature Values')
plt.show()

# %%
data = train[['Income (USD/Month)']]
plt.boxplot(data.values)
plt.xticks(range(1, len(data.columns) + 1), data.columns)
plt.title('Box Plot of Income in USD per month')
plt.ylabel('Feature Values')
plt.show()

# %%
# Exploratory data analysis(EDA) 

##Introduction
#XYZ is a private firm in US. Due to remarkable growth in the Cab Industry in last few years and multiple key players in 
#the market is planning for an investment in Cab industry.

##Objective
#Provide actionable insights to help XYZ firm in identifying the right company for making investment.

##Data Description
#we have 4 individual dataset files
#Cab_Data.csv – this file includes details of transaction for 2 cab companies

#Customer_ID.csv – this is a mapping table that contains a unique identifier which links the customer’s demographic details

#Transaction_ID.csv – this is a mapping table that contains transaction to customer mapping and payment mode

#City.csv – this file contains list of US cities, their population and number of cab users

# I have merged all 4 datasets into 1 dataset(merge_final) to perform further analysis.
# merge_final file has 359392 rows and 16 columns(float64(3), int64(5), object(8))
# there are no missing values in the data.

##Data Cleaning and Preprocessing
#We have split the data into train, validation and test set in 40:40:20 ratio
#to identify the outliers, we had boxplot for the columns KM Travelled, Price Charged, Cost of Trip and Income.

##Univariate analysis
#Outliers are present in Price_Charged feature but due to unavailability of trip duration details ,we are not treating 
#this as an outlier.

##Key findings and insights
#Profit of rides are calculated keeping other factors constant and only Price Charged and Cost of Trip features used 
#to calculate profit

##Hypothesis
#1. Customers used more yellow cabs when compared to pink cabs based on the percentage and the year wise insights.

#2. Yellow cab’s average profit per KM is almost three times the average profit per KM of the Pink cab

#3. Analysing through age, gender and income variables, Yellow cab is performing better than pink cab

#4. By analysing payment mode and users, card and cash payments in yellow cab are 3 times than the cash/card payments in 
#pink cab

#5. Yellow cab is used more often compared to pink cab in highly populated cities.

#6. The forecast for yellow cab seems more profitable than pink cab based on this data analysis.

# %%
merge_final.describe()
# Out:
#        Transaction ID   KM Travelled  Price Charged   Cost of Trip  \
# count    3.593920e+05  359392.000000  359392.000000  359392.000000
# mean     1.022076e+07      22.567254     423.443311     286.190113
# std      1.268058e+05      12.233526     274.378911     157.993661
# min      1.000001e+07       1.900000      15.600000      19.000000
# 25%      1.011081e+07      12.000000     206.437500     151.200000
# 50%      1.022104e+07      22.440000     386.360000     282.480000
# 75%      1.033094e+07      32.960000     583.660000     413.683200
# max      1.044011e+07      48.000000    2048.030000     691.200000
#
#        Customer ID_x  Customer ID_y            Age  Income (USD/Month)
# count  359392.000000  359392.000000  359392.000000       359392.000000
# mean    19191.652115   19191.652115      35.336705        15048.822937
# std     21012.412463   21012.412463      12.594234         7969.409482
# min         1.000000       1.000000      18.000000         2000.000000
# ...

# %%
merge_final.corr()
# Out:
#                     Transaction ID  KM Travelled  Price Charged  Cost of Trip  \
# Transaction ID            1.000000     -0.001429      -0.052902     -0.003462
# KM Travelled             -0.001429      1.000000       0.835753      0.981848
# Price Charged            -0.052902      0.835753       1.000000      0.859812
# Cost of Trip             -0.003462      0.981848       0.859812      1.000000
# Customer ID_x            -0.016912      0.000389      -0.177324      0.003077
# Customer ID_y            -0.016912      0.000389      -0.177324      0.003077
# Age                      -0.001267     -0.000369      -0.003084     -0.000189
# Income (USD/Month)       -0.001570     -0.000544       0.003228     -0.000633
#
#                     Customer ID_x  Customer ID_y       Age  Income (USD/Month)
# Transaction ID          -0.016912      -0.016912 -0.001267           -0.001570
# KM Travelled             0.000389       0.000389 -0.000369           -0.000544
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(merge_final)
plt.show()
